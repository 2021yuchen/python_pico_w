# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)
# Out:
# 3
# 1
# 8
# 6
# 3
# 2
# 6
# 10
# 2
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 for i in range(100):
#       5     print(random.randint(1,10))
# ----> 6     time.sleep(1)
#
# KeyboardInterrupt:

# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926828831","type":"CreateEvent","actor":{"id":29599851,"login":"springmuffin","display_login":"springmuffin","gravatar_id":"","url":"https://api.github.com/users/springmuffin","avatar_url":"https://avatars.githubusercontent.com/u/29599851?"},"repo":{"id":857270320,"name":"springmuffin/GoLang-Tasks","url":"https://api.github.com/repos/springmuffin/GoLang-Tasks"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":"This repo is for practicing golang tasks received during training. ","pusher_type":"user"},"public":true,"created_at":"2024-09-14T07:51:10Z"},{"id":"41926828829","type":"PushEvent","actor":{"id":26007343,"login":"octobocto","display_login":"octobocto","gravatar_id":"","url":"https://api.github.com/users/octobocto","avatar_url":"https://avatars.githubusercontent.com/u/26007343?"},"repo":{"id":708035292,"name":"LayerTwo-Labs/sidesail","url":"https://api.github.com/repos/LayerTwo-Labs/sidesail"},"payload":{"repository_id":708035292,"push_
# ...
